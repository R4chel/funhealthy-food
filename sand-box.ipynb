# %%
import csv
import numpy as np
import pandas as pd
from collections import Counter

# %%
def load_health_ratings():
    with open('data/DOHMH_New_York_City_Restaurant_Inspection_Results.csv', 'r') as csvfile:
        data = pd.read_csv(csvfile,  quotechar='"')
        return data

# %%
data = load_health_ratings()
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3006: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
data
# Out:
#            CAMIS                            DBA           BORO    BUILDING  \
# 0       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 1       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 2       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 3       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 4       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 5       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 6       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 7       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 8       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 9       30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# 10      30075445          MORRIS PARK BAKE SHOP          BRONX        1007
# ...

# %%
counts = Counter(data['VIOLATION CODE'])

# %%
counts.most_common(3)
# Out:
# [('10F', 64574), ('08A', 46381), ('02G', 40089)]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
dates = data["INSPECTION DATE"]

# %%
sorted_data = data.sort_values(by="INSPECTION DATE")

# %%
len(dates)
# Out:
# 484357

# %%
# Out:
#            CAMIS                                        DBA       BORO  \
# 71153   40795070               TERMINAL1 EMPLOYEE CAFETERIA     QUEENS
# 71154   40795070               TERMINAL1 EMPLOYEE CAFETERIA     QUEENS
# 71155   40795070               TERMINAL1 EMPLOYEE CAFETERIA     QUEENS
# 286027  41570741                            JEN'S ROTI SHOP   BROOKLYN
# 282070  41563217                           NELLY SPILLANE'S  MANHATTAN
# 289090  41576339                     ASYA INDIAN RESTAURANT   BROOKLYN
# 282069  41563217                           NELLY SPILLANE'S  MANHATTAN
# 279428  41558439                  MARIA & TONY'S RESTAURANT   BROOKLYN
# 279427  41558439                  MARIA & TONY'S RESTAURANT   BROOKLYN
# 279426  41558439                  MARIA & TONY'S RESTAURANT   BROOKLYN
# 279425  41558439                  MARIA & TONY'S RESTAURANT   BROOKLYN
# 21319   40395036       AMERICAN AIRLINES EMPLOYEE CAFETERIA     QUEENS
# ...

# %%
date_set = set(dates)

# %%
len(date_set)
# Out:
# 1335

# %%
date_list = list(date_set)

# %%
sorted(date_list)
# Out:
# ['01/01/1900',
#  '01/02/2013',
#  '01/02/2014',
#  '01/02/2015',
#  '01/03/2012',
#  '01/03/2013',
#  '01/03/2014',
#  '01/03/2015',
#  '01/04/2012',
#  '01/04/2013',
#  '01/04/2014',
#  '01/05/2012',
#  '01/05/2013',
#  '01/05/2014',
#  '01/05/2015',
#  '01/06/2012',
#  '01/06/2013',
#  '01/06/2014',
#  '01/06/2015',
#  '01/07/2012',
#  '01/07/2013',
#  '01/07/2014',
#  '01/07/2015',
#  '01/08/2013',
#  '01/08/2014',
#  '01/08/2015',
#  '01/09/2012',
#  '01/09/2013',
#  '01/09/2014',
#  '01/09/2015',
#  '01/10/2012',
#  '01/10/2013',
#  '01/10/2014',
#  '01/10/2015',
#  '01/11/2012',
#  '01/11/2013',
#  '01/11/2014',
#  '01/12/2012',
#  '01/12/2013',
#  '01/12/2015',
#  '01/13/2012',
#  '01/13/2014',
#  '01/13/2015',
#  '01/14/2012',
#  '01/14/2013',
#  '01/14/2014',
#  '01/14/2015',
#  '01/15/2013',
#  '01/15/2014',
#  '01/15/2015',
#  '01/16/2013',
#  '01/16/2014',
#  '01/16/2015',
#  '01/17/2012',
#  '01/17/2013',
#  '01/17/2014',
#  '01/17/2015',
#  '01/18/2012',
# ...

# %%
list(set(x[-4:] for x in date_list))
# Out:
# ['2013', '2015', '2014', '2011', '2010', '1900', '2012']

# %%
None is not ''
# Out:
# True

# %%
dir(data)
# Out:
# ['ACTION',
#  'BORO',
#  'BUILDING',
#  'CAMIS',
#  'DBA',
#  'GRADE',
#  'PHONE',
#  'SCORE',
#  'STREET',
#  'T',
#  'ZIPCODE',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
data.columns
# Out:
# Index([u'CAMIS', u'DBA', u'BORO', u'BUILDING', u'STREET', u'ZIPCODE', u'PHONE',
#        u'CUISINE DESCRIPTION', u'INSPECTION DATE', u'ACTION',
#        u'VIOLATION CODE', u'VIOLATION DESCRIPTION', u'CRITICAL FLAG', u'SCORE',
#        u'GRADE', u'GRADE DATE', u'RECORD DATE', u'INSPECTION TYPE'],
#       dtype='object')

# %%
pd.isnull(data["GRADE"].iloc[-1])
# Out:
# True

# %%
clean_data = data[~data['INSPECTION DATE'].isin(['01/01/1900'])]

# %%
len(clean_data)
# Out:
# 483483

# %%
len(data)
# Out:
# 484357

# %%
cleaner_data = clean_data[~pd.isnull(clean_data['GRADE'])]

# %%
type(float("nan"))
# Out:
# float

# %%
len(cleaner_data)
# Out:
# 221053

# %%
cleaner_data
# Out:
#            CAMIS                             DBA       BORO    BUILDING  \
# 0       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 1       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 3       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 4       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 12      30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 13      30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 22      30112340                         WENDY'S   BROOKLYN  469
# 23      30112340                         WENDY'S   BROOKLYN  469
# 24      30112340                         WENDY'S   BROOKLYN  469
# 25      30112340                         WENDY'S   BROOKLYN  469
# 29      30112340                         WENDY'S   BROOKLYN  469
# 30      30112340                         WENDY'S   BROOKLYN  469
# 31      30112340                         WENDY'S   BROOKLYN  469
# ...

# %%
violation_codes = set(clean_data['VIOLATION CODE'])

# %%
import re
ve = [(c, re.sub(r'\xc3\x82', '', str(d))) for c, d in zip(clean_data['VIOLATION CODE'], clean_data['VIOLATION DESCRIPTION'])]

# %%
len(set(ve))
# Out:
# 101

# %%
len(dict(ve))
# Out:
# 97

# %%
len(v)
# Out:
# 483483

# %%
vs = set(v)

# %%
len(vs)
# Out:
# 108

# %%
len(violation_codes)
# Out:
# 97

# %%
vf = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-2f2a79bab886> in <module>()
# ----> 1 v - list(vs)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
vs
# Out:
# {(nan, nan),
#  ('02A', 'Food not cooked to required minimum temperature.'),
#  ('02B', 'Hot food item not held at or above 140\xc2\xba F.'),
#  ('02B', 'Hot food item not held at or above 140\xc3\x82\xc2\xba F.'),
#  ('02C',
#   'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65\xc2\xba F or above within 2 hours.'),
#  ('02C',
#   'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65\xc3\x82\xc2\xba F or above within 2 hours.'),
#  ('02D',
#   'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140\xc2\xba F within 2 hours.'),
#  ('02D',
#   'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140\xc3\x82\xc2\xba F within 2 hours.'),
#  ('02E',
# ...

# %%
s = 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140\xc3\x82\xc2\xba F to 70\xc3\x82\xc2\xba F or l'

# %%
re.sub(r'\xc3\x82', '', s)
# Out:
# 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140\xc2\xba F to 70\xc2\xba F or l'

# %%
clean_data
# Out:
#            CAMIS                          DBA       BORO    BUILDING  \
# 0       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 1       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 2       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 3       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 4       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 5       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 6       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 7       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 8       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 9       30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 10      30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 11      30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# 12      30075445        MORRIS PARK BAKE SHOP      BRONX        1007
# ...
